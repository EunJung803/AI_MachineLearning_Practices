# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('glass.csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe  \
# 0    1.51793  12.79  3.50  1.12  73.03  0.64   8.77  0.00  0.00
# 1    1.51643  12.16  3.52  1.35  72.89  0.57   8.53  0.00  0.00
# 2    1.51793  13.21  3.48  1.41  72.64  0.59   8.43  0.00  0.00
# 3    1.51299  14.40  1.74  1.54  74.55  0.00   7.59  0.00  0.00
# 4    1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.00  0.24
# 5    1.51655  12.75  2.85  1.44  73.27  0.57   8.79  0.11  0.22
# 6    1.51779  13.64  3.65  0.65  73.00  0.06   8.93  0.00  0.00
# 7    1.51837  13.14  2.84  1.28  72.85  0.55   9.07  0.00  0.00
# 8    1.51545  14.14  0.00  2.68  73.39  0.08   9.07  0.61  0.05
# 9    1.51789  13.19  3.90  1.30  72.33  0.55   8.44  0.00  0.28
# 10   1.51625  13.36  3.58  1.49  72.72  0.45   8.21  0.00  0.00
# 11   1.51743  12.20  3.25  1.16  73.55  0.62   8.90  0.00  0.24
# 12   1.52223  13.21  3.77  0.79  71.99  0.13  10.02  0.00  0.00
# 13   1.52121  14.03  3.76  0.58  71.79  0.11   9.65  0.00  0.00
# 14   1.51665  13.14  3.45  1.76  72.48  0.60   8.38  0.00  0.17
# 15   1.51707  13.48  3.48  1.71  72.52  0.62   7.99  0.00  0.00
# 16   1.51719  14.75  0.00  2.00  73.02  0.00   8.53  1.59  0.08
# 17   1.51629  12.71  3.33  1.49  73.28  0.67   8.24  0.00  0.00
# 18   1.51994  13.27  0.00  1.76  73.03  0.47  11.32  0.00  0.00
# 19   1.51811  12.96  2.96  1.43  72.92  0.60   8.79  0.14  0.00
# 20   1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.00  0.17
# 21   1.52475  11.45  0.00  1.88  72.19  0.81  13.24  0.00  0.34
# 22   1.51841  12.93  3.74  1.11  72.28  0.64   8.96  0.00  0.22
# 23   1.51754  13.39  3.66  1.19  72.79  0.57   8.27  0.00  0.11
# 24   1.52058  12.85  1.61  2.17  72.18  0.76   9.70  0.24  0.51
# 25   1.51569  13.24  3.49  1.47  73.25  0.38   8.03  0.00  0.00
# 26   1.51590  12.82  3.52  1.90  72.86  0.69   7.97  0.00  0.00
# 27   1.51683  14.56  0.00  1.98  73.29  0.00   8.52  1.57  0.07
# 28   1.51687  13.23  3.54  1.48  72.84  0.56   8.10  0.00  0.00
# 29   1.51610  13.33  3.53  1.34  72.67  0.56   8.33  0.00  0.00
# ..       ...    ...   ...   ...    ...   ...    ...   ...   ...
# 184  1.51783  12.69  3.54  1.34  72.95  0.57   8.75  0.00  0.00
# 185  1.51711  14.23  0.00  2.08  73.36  0.00   8.62  1.67  0.00
# 186  1.51736  12.78  3.62  1.29  72.79  0.59   8.70  0.00  0.00
# 187  1.51808  13.43  2.87  1.19  72.84  0.55   9.03  0.00  0.00
# 188  1.51670  13.24  3.57  1.38  72.70  0.56   8.44  0.00  0.10
# 189  1.52043  13.38  0.00  1.40  72.25  0.33  12.50  0.00  0.00
# 190  1.51900  13.49  3.48  1.35  71.95  0.55   9.00  0.00  0.00
# 191  1.51778  13.21  2.81  1.29  72.98  0.51   9.02  0.00  0.09
# 192  1.51905  14.00  2.39  1.56  72.37  0.00   9.57  0.00  0.00
# 193  1.51531  14.38  0.00  2.66  73.10  0.04   9.08  0.64  0.00
# 194  1.51916  14.15  0.00  2.09  72.74  0.00  10.88  0.00  0.00
# 195  1.51841  13.02  3.62  1.06  72.34  0.64   9.13  0.00  0.15
# 196  1.51590  13.02  3.58  1.51  73.12  0.69   7.96  0.00  0.00
# 197  1.51593  13.25  3.45  1.43  73.17  0.61   7.86  0.00  0.00
# 198  1.51640  12.55  3.48  1.87  73.23  0.63   8.08  0.00  0.09
# 199  1.51663  12.93  3.54  1.62  72.96  0.64   8.03  0.00  0.21
# 200  1.51690  13.33  3.54  1.61  72.54  0.68   8.11  0.00  0.00
# 201  1.51869  13.19  3.37  1.18  72.72  0.57   8.83  0.00  0.16
# 202  1.51776  13.53  3.41  1.52  72.04  0.58   8.79  0.00  0.00
# 203  1.51775  12.85  3.48  1.23  72.97  0.61   8.56  0.09  0.22
# 204  1.51860  13.36  3.43  1.43  72.26  0.51   8.60  0.00  0.00
# 205  1.51720  13.38  3.50  1.15  72.85  0.50   8.43  0.00  0.00
# 206  1.51623  14.20  0.00  2.79  73.46  0.04   9.04  0.40  0.09
# 207  1.51618  13.53  3.55  1.54  72.99  0.39   7.78  0.00  0.00
# 208  1.51761  12.81  3.54  1.23  73.24  0.58   8.39  0.00  0.00
# 209  1.51610  13.42  3.40  1.22  72.69  0.59   8.32  0.00  0.00
# 210  1.51592  12.86  3.52  2.12  72.66  0.69   7.97  0.00  0.00
# 211  1.51613  13.92  3.52  1.25  72.88  0.37   7.94  0.00  0.14
# 212  1.51689  12.67  2.88  1.71  73.21  0.73   8.54  0.00  0.00
# 213  1.51852  14.09  2.19  1.66  72.67  0.00   9.32  0.00  0.00
#
#                        Type
# 0        'build wind float'
# 1        'vehic wind float'
# 2        'build wind float'
# 3                 tableware
# 4    'build wind non-float'
# 5    'build wind non-float'
# 6        'vehic wind float'
# 7        'build wind float'
# 8                 headlamps
# 9    'build wind non-float'
# 10   'build wind non-float'
# 11   'build wind non-float'
# 12       'build wind float'
# 13       'vehic wind float'
# 14       'vehic wind float'
# 15   'build wind non-float'
# 16                headlamps
# 17   'build wind non-float'
# 18               containers
# 19   'build wind non-float'
# 20       'build wind float'
# 21   'build wind non-float'
# 22   'build wind non-float'
# 23       'build wind float'
# 24               containers
# 25   'build wind non-float'
# 26   'build wind non-float'
# 27                headlamps
# 28   'build wind non-float'
# 29       'vehic wind float'
# ..                      ...
# 184      'build wind float'
# 185               headlamps
# 186      'build wind float'
# 187      'build wind float'
# 188      'vehic wind float'
# 189              containers
# 190      'build wind float'
# 191      'build wind float'
# 192               tableware
# 193               headlamps
# 194               tableware
# 195  'build wind non-float'
# 196  'build wind non-float'
# 197  'build wind non-float'
# 198  'build wind non-float'
# 199  'build wind non-float'
# 200  'build wind non-float'
# 201      'build wind float'
# 202      'vehic wind float'
# 203      'build wind float'
# 204  'build wind non-float'
# 205      'build wind float'
# 206               headlamps
# 207      'build wind float'
# 208      'build wind float'
# 209      'vehic wind float'
# 210  'build wind non-float'
# 211  'build wind non-float'
# 212  'build wind non-float'
# 213               tableware
#
# [214 rows x 10 columns]

# %%
X=df.values[:, :-1]
y=df.values[:, -1]

# %%
print(X)
# Out:
# [[1.51793 12.79 3.5 ... 8.77 0.0 0.0]
#  [1.51643 12.16 3.52 ... 8.53 0.0 0.0]
#  [1.51793 13.21 3.48 ... 8.43 0.0 0.0]
#  ...
#  [1.51613 13.92 3.52 ... 7.94 0.0 0.14]
#  [1.51689 12.67 2.88 ... 8.54 0.0 0.0]
#  [1.51852 14.09 2.19 ... 9.32 0.0 0.0]]

# %%
print(y)
# Out:
# ["'build wind float'" "'vehic wind float'" "'build wind float'"
#  'tableware' "'build wind non-float'" "'build wind non-float'"
#  "'vehic wind float'" "'build wind float'" 'headlamps'
#  "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind float'" "'vehic wind float'"
#  "'vehic wind float'" "'build wind non-float'" 'headlamps'
#  "'build wind non-float'" 'containers' "'build wind non-float'"
#  "'build wind float'" "'build wind non-float'" "'build wind non-float'"
#  "'build wind float'" 'containers' "'build wind non-float'"
#  "'build wind non-float'" 'headlamps' "'build wind non-float'"
#  "'vehic wind float'" "'build wind non-float'" "'vehic wind float'"
#  'tableware' "'build wind non-float'" "'build wind float'"
#  "'build wind float'" "'build wind float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'" "'build wind float'"
#  "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'vehic wind float'" "'build wind float'"
#  'containers' "'build wind float'" "'build wind float'"
#  "'build wind non-float'" "'build wind float'" "'build wind non-float'"
#  "'build wind float'" "'build wind non-float'" 'headlamps'
#  "'build wind float'" 'headlamps' "'build wind float'"
#  "'vehic wind float'" "'build wind non-float'" "'build wind non-float'"
#  "'build wind float'" "'build wind float'" "'build wind float'"
#  "'build wind float'" 'headlamps' "'build wind float'"
#  "'vehic wind float'" "'build wind non-float'" "'build wind float'"
#  'tableware' "'build wind non-float'" 'tableware' "'build wind non-float'"
#  "'build wind float'" "'build wind non-float'" "'build wind float'"
#  "'build wind float'" "'vehic wind float'" "'build wind float'"
#  "'build wind float'" "'build wind float'" "'vehic wind float'"
#  "'build wind float'" 'containers' "'build wind non-float'"
#  "'build wind non-float'" "'build wind float'" "'build wind float'"
#  "'build wind non-float'" 'headlamps' "'build wind float'"
#  "'build wind float'" 'tableware' 'headlamps' "'build wind float'"
#  'headlamps' "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind float'" "'build wind non-float'"
#  'headlamps' 'headlamps' 'headlamps' 'containers' "'build wind non-float'"
#  'headlamps' "'build wind float'" 'containers' "'build wind non-float'"
#  'headlamps' "'build wind float'" 'headlamps' "'vehic wind float'"
#  'headlamps' "'build wind non-float'" 'headlamps' "'build wind non-float'"
#  "'build wind float'" "'build wind non-float'" "'build wind float'"
#  "'build wind non-float'" "'build wind non-float'" 'containers'
#  "'build wind float'" 'headlamps' 'headlamps' "'build wind float'"
#  "'build wind float'" "'build wind non-float'" "'build wind non-float'"
#  'headlamps' "'build wind float'" 'containers' "'build wind float'"
#  "'build wind float'" "'build wind non-float'" "'build wind float'"
#  "'build wind non-float'" "'build wind float'" "'build wind float'"
#  "'build wind float'" 'containers' "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" 'headlamps' "'build wind float'"
#  "'build wind non-float'" "'build wind non-float'" "'vehic wind float'"
#  "'build wind float'" 'headlamps' 'containers' "'build wind float'"
#  "'build wind non-float'" "'build wind non-float'" "'build wind float'"
#  'headlamps' 'containers' "'build wind non-float'" "'build wind float'"
#  "'build wind float'" "'build wind non-float'" "'build wind non-float'"
#  'headlamps' "'build wind non-float'" "'build wind non-float'"
#  "'build wind float'" 'headlamps' "'build wind float'" 'headlamps'
#  "'build wind float'" "'build wind float'" 'containers' 'tableware'
#  "'build wind non-float'" "'build wind non-float'" "'vehic wind float'"
#  "'build wind non-float'" "'build wind float'" 'headlamps'
#  "'build wind float'" "'build wind float'" "'vehic wind float'"
#  'containers' "'build wind float'" "'build wind float'" 'tableware'
#  'headlamps' 'tableware' "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'" "'build wind float'"
#  "'vehic wind float'" "'build wind float'" "'build wind non-float'"
#  "'build wind float'" 'headlamps' "'build wind float'"
#  "'build wind float'" "'vehic wind float'" "'build wind non-float'"
#  "'build wind non-float'" "'build wind non-float'" 'tableware']

# %%
clf = KNeighborsClassifier(n_neighbors=10, weights='uniform', metric='euclidean')

# %%
cv=KFold(n_splits=10, shuffle=True, random_state=0)
cv_results=cross_val_score(clf,X,y,cv=cv)

print(cv_results.mean())
# Out:
# 0.6199134199134199

# %%
clf.fit(X,y)
pred_y=clf.predict([[1.5,  13, 1.5, 1.5, 70, 0.5, 8.9, 0.1, 0.2]])
print(pred_y)
# Out:
# ["'build wind non-float'"]

# %%
clf = KNeighborsClassifier(n_neighbors=20, weights='uniform')
clf2 = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf3 = KNeighborsClassifier(n_neighbors=1, weights='uniform')

results=cross_val_score(clf,X,y,cv=cv)
results2=cross_val_score(clf2,X,y,cv=cv)
results3=cross_val_score(clf3,X,y,cv=cv)

print("20 neighbors: {}".format(results.mean()))
print("5 neighbors: {}".format(results2.mean()))
print("1 neighbors: {}".format(results3.mean()))
# Out:
# 20 neighbors: 0.6155844155844156
# 5 neighbors: 0.648051948051948
# 1 neighbors: 0.7370129870129871
